# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class NodoBinario:
    def __init__( self , value , left = None , rigth = None ):
        self.data = value
        self.left = left
        self.rigth = rigth

class NodoTernario:
    def __init__( self , value , left = None , center = None, rigth = None ):
        self.data = value
        self.left = left
        self.center = center
        self.rigth = rigth

# %%
arbol1 = NodoBinario("R", NodoBinario("C"), NodoBinario("H"))
print(arbol1.rigth.data)

arbol2 = NodoTernario(4, NodoTernario(3,\
        NodoTernario(5, left=NodoTernario(2)),\
         NodoTernario(5), NodoTernario(2)), None , NodoTernario(5))
print(arbol2.left.rigth.data)
print(arbol2.data)
print(arbol2.left.center.data)
print(arbol2.rigth.left)
print(arbol2.left.left.left.data)
print("---- sin usar la palabra left en el print ----")
ejemplo = arbol2.left.left.left.data
print(ejemplo)
print("---- otra forma ----")
aux = arbol2
while (aux.left != None):
    aux = aux.left
print(aux.data)
# Out:
# H
# 2
# 4
# 5
# None
# 2
# ---- sin usar la palabra left en el print ----
# 2
# ---- otra forma ----
# 2

# %%
root = NodoBinario("Santi", None, NodoBinario("Jesus", NodoBinario("Pedro", None, NodoBinario("Pedro JR", None, None)), None))
#root = NodoBinario("Santi",None,NodoBinario("Jesus",NodoBinario("Pedro",None,NodoBinario(" jr"))))
print(root.rigth.left.rigth.data)
# Out:
# Pedro JR

# %%
class NodoBinario:
    def __init__( self , value , left = None , rigth = None ):
        self.data = value
        self.left = left
        self.rigth = rigth

class BinarySearchTree:
    def __init__( self ):
        self.root = None
    
    def insert( self , value ):
        if self.root == None:
            self.root = NodoBinario( value )
        else:
            self.__insert_nodo( self.root , value )
    
    def __insert_nodo( self , nodo , value ):
        if nodo.data == value:
            pass
        elif value < nodo.data: #ir a la izquierda
            if nodo.left == None:
                nodo.left = NodoBinario( value )
            else:
                self.__insert_nodo( nodo.left , value )
        else: #ir a la derecha
            if nodo.rigth == None:
                nodo.rigth = NodoBinario( value )
            else:
                self.__insert_nodo( nodo.rigth , value )

    def transeversal( self , formato = "posorden"):
        if formato == "posorden":
            self.recorrido_pos( self.root )
        elif formato == "preorden":
            self.recorrido_pre( self.root )
        else: #inorden
            self.recorrido_in( self.root )
        print("")

    def recorrido_pos( self , nodo ):
        if nodo != None:
            self.recorrido_pos( nodo.left )
            self.recorrido_pos( nodo.rigth )
            print( str( nodo.data ), end=", ")

    def recorrido_pre( self , nodo ):
        if nodo != None:
            print( str( nodo.data ), end=", ")
            self.recorrido_pre( nodo.left )
            self.recorrido_pre( nodo.rigth )
    
    def recorrido_in( self , nodo ):
        if nodo != None:
            self.recorrido_in( nodo.left )
            print( str( nodo.data ), end=", ")
            self.recorrido_in( nodo.rigth )

    def search( self , value ):
        if self.root == None:
            print("El arbol está vacío")
            return None
        else:
            self.__research( self.root , value )

    def __research( self , nodo , value ):
        if nodo.data == None:
            print("El dato no existe en el árbol")
            return None
        elif nodo.data == value:
            print("Encontrado")
            return nodo
        elif value < nodo.data:
            return self.__buscar( nodo.left , value )
        else:
            return self.__buscar( nodo.rigth , value )

# %%
arb1 = BinarySearchTree()
arb1.insert(60)
arb1.insert(30)
arb1.insert(15)
arb1.insert(40)
arb1.transeversal("posorden")
arb1.transeversal("preorden")
arb1.transeversal("inorden")
# Out:
# 15, 40, 30, 60,
# 60, 30, 15, 40,
# 15, 30, 40, 60,

# %%
class BinaryNode:
    def __init__( self , value , left=None , rigth= None ):
        self.data = value
        self.left = left
        self.rigth = rigth

class BinarySearchTree:
    def __init__( self ):
        self.root = None
    
    def insert( self , value ):
        if self.root == None:
            self.root = BinaryNode( value )
        else:
            self.__insert_nodo( self.root , value )
        
    def __insert_nodo(self , nodo , value ):
        if nodo.data == value: 
            pass
        elif value < nodo.data:# ir a la izq
            if nodo.left == None:
                nodo.left = BinaryNode( value )
            else:
                self.__insert_nodo( nodo.left , value )
        else:  # ir a la derecha
            if nodo.rigth == None:
                nodo.rigth = BinaryNode( value )
            else:
                self.__insert_nodo( nodo.rigth , value )
    
    def transversal( self , formato = "posorden"):
        if formato == "posorden":
            self.recorrido_pos( self.root )
        elif formato == "preorden":
            self.recorrido_pre(self.root )
        else: # inorden
            self.recorrido_in( self.root )
        print()

    def  recorrido_pos( self , nodo ):
        if nodo != None:
            self.recorrido_pos( nodo.left )
            self.recorrido_pos( nodo.rigth )
            print( str(nodo.data) , end=" , " )
    
    def  recorrido_pre( self , nodo ):
        if nodo != None:
            print( str(nodo.data) , end=" , " )
            self.recorrido_pre( nodo.left )
            self.recorrido_pre( nodo.rigth )
    
    def  recorrido_in( self , nodo ):
        if nodo != None:
            self.recorrido_in( nodo.left )
            print( str(nodo.data) , end=" , " )
            self.recorrido_in( nodo.rigth ) 

    def search( self , value ):
        if self.root == None:
            print("El árbol está vacío")
            return None
        else:
            return self.__search( self.root , value )

    def __search( self , nodo , value ):
        if nodo == None:
            print("El dato no existe en el árbol") 
            return None
        elif nodo.data == value:
            print("Encontrado", nodo.data)
            return nodo
        elif value < nodo.data:
            return self.__search( nodo.left , value  )
        else:
            return self.__search( nodo.rigth , value  )
    
    def remove( self , value ):
        if self.root == None:
            print("El árbol está vacío, no hay nada que borrar")
            return None
        else:
            return self.__remove( self.root , value )

    def __remove( self , nodo , value ):
        if nodo == None:
            print("El dato a borrar no existe en el árbol") 
            return None
        elif nodo.data == value:
            print("A borrar: ", nodo.data)
            if nodo.left == None and nodo.rigth == None:
                print(f"El nodo {nodo.data} es un Nodo hoja ")
                nodo = None
            elif nodo.left == None or nodo.rigth == None:
                print(f"El nodo {nodo.data} tiene solo un hijo ")
                
            else:
                print(f"El nodo {nodo.data} tiene dos hijos ")
        elif value < nodo.data:
            return self.__remove( nodo.left , value  )
        else:
            return self.__remove( nodo.rigth , value  )

# %%
abb = BinarySearchTree()
abb.insert(30)
abb.insert(15)
abb.insert(45)
abb.insert(12)
abb.insert(17)
abb.insert(50)
abb.insert(55)
abb.insert(35)
abb.insert(2)
abb.insert(1)
abb.insert(80)
abb.insert(60)
abb.transversal("posorden")
abb.transversal("preorden")
abb.transversal("inorden")
res = abb.search(45)
print(res)
print(res.data)
print(res.left.data)
abb.remove(1)
abb.transversal("posorden")
# Out:
# 1 , 2 , 12 , 17 , 15 , 35 , 60 , 80 , 55 , 50 , 45 , 30 ,
# 30 , 15 , 12 , 2 , 1 , 17 , 45 , 35 , 50 , 55 , 80 , 60 ,
# 1 , 2 , 12 , 15 , 17 , 30 , 35 , 45 , 50 , 55 , 60 , 80 ,
# Encontrado 45
# <__main__.BinaryNode object at 0x7f9d42687850>
# 45
# 35
# A borrar:  1
# El nodo 1 es un Nodo hoja
